# %%
import pandas as pd

# %%
# 读取清洗好的数据
mask_data_clean = pd.read_csv('mask_data_clean.csv',encoding = 'utf-8')

# %%
# 读取清洗好的数据
mask_data_clean = pd.read_csv('mask_data_clean.csv',encoding = 'utf-8')

# %%
# 导入matplotlib库的pyplot模块
from matplotlib import pyplot as plt
# 设置中文字体
plt.rcParams['font.family'] = ['FangSong']

# %%
# 绘制单条折线图
li_jian.plot(kind='line', figsize=(7, 7), title='李健月考成绩')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12032/1280912661.py in <module>
#       1 # 绘制单条折线图
# ----> 2 li_jian.plot(kind='line', figsize=(7, 7), title='李健月考成绩')
#
# NameError: name 'li_jian' is not defined

# %%
# 创建李健的数据
li_jian = pd.Series([80, 85, 89, 91, 88, 95],
                    index=['2月', '3月', '4月', '5月', '6月', '7月'])
# 查看li_jian
li_jian
# Out:
# 2月    80
# 3月    85
# 4月    89
# 5月    91
# 6月    88
# 7月    95
# dtype: int64

# %%
# 绘制单条折线图
li_jian.plot(kind='line', figsize=(7, 7), title='李健月考成绩')
# Out:
# <AxesSubplot:title={'center':'李健月考成绩'}>

# %%
# 创建三位学生成绩的df
students_grade = pd.DataFrame({'李健': [80, 85, 89, 91, 88, 95],
                               '王聪': [95, 92, 90, 85, 75, 80],
                               '过凡': [90, 91, 92, 91, 90, 91]
                              }, index=['2月', '3月', '4月', '5月', '6月', '7月'])
# 绘制多条折线图
students_grade.plot(kind='line', figsize=(7, 7), title='月考成绩')
# Out:
# <AxesSubplot:title={'center':'月考成绩'}>
